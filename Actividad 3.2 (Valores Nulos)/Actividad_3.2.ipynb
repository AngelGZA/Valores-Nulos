# %%
#Importamos librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Carga desde un archivo .csv sin indice
data1= pd.read_csv('Datos_LosAngeles_EstadosUnidos.csv')
data1
# Out:
#        last_scraped           source  \
# 0             45540      city scrape
# 1             45540  previous scrape
# 2             45540      city scrape
# 3             45539      city scrape
# 4             45540      city scrape
# ...             ...              ...
# 45528         45540  previous scrape
# 45529         45540  previous scrape
# 45530         45540  previous scrape
# 45531         45540      city scrape
# 45532         45540      city scrape
#
#                                              description  \
# 0      The whole group will enjoy easy access to ever...
# 1                                                    NaN
# 2      Charming, renovated home in the Beverly Hills ...
# 3               Relax in this unique and serene retreat.
# 4      Welcome to our stunning apartment nestled in t...
# ...                                                  ...
# 45528                                                NaN
# ...

# %%
#Identificar valores nulos por columna
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# last_scraped                                        0
# source                                              0
# description                                      1433
# neighborhood_overview                           22421
# host_name                                           2
# host_since                                          2
# host_response_time                              10088
# host_acceptance_rate                             9683
# host_is_superhost                                1252
# host_neighbourhood                               9985
# host_total_listings_count                           2
# host_verifications                                  2
# host_has_profile_pic                                2
# host_identity_verified                              2
# neighbourhood_cleansed                              0
# latitude                                            0
# longitude                                           0
# ...

# %%
#Identificar valores nulos para dataframe
valores_nulos=data1.isnull().sum().sum()
valores_nulos
# Out:
# np.int64(162986)

# %% [markdown]
# **Metodos de Sustitucion para Valores Nulos.**

# %%
#Realizamos una copia del dataframe
data2=data1.copy()

# %%
#Sustitucion de valores nulos por un valor de texto dado que no proporcionan una descripcion, llenarlo con una descripcion diciendo que no esta disponible sirve para no dejar los valores nulos.
data2["description"]=data2["description"].fillna("No description available")

# %%
#Sustitucion de valores nulos por un valor de texto, al igual que la columna anterior, la use para dar entender que la informacion no fue proporciona y va acorde con el tipo de valor que tiene la columna.
data2["neighborhood_overview"]=data2["neighborhood_overview"].fillna("No overview available")

# %%
#Sustitucion de valores nulos por un valor de texto, al igual que la columna anterior, y esta vez por dos columnas opte por sustituir el valor nulo por desconocido, y dado que es acorde y se puede aplicar a diferentes columnas, asi lo hice.
data2[["host_name", "host_response_time"]]=data2[["host_name", "host_response_time"]].fillna("Unknown")

# %%
#Sustitucion de valores nulos por valores no nulos hacia adelante, ocupe este metodo y a varias columnas ya que visualizando los valores, me di cuenta el valor adelante de el suele ser el mismo o similar al de la columna y queda perfecto como sustitucion de los valores nulos 
data2[["host_since", "host_neighbourhood", "bathrooms_text"]]=data2[["host_since", "host_neighbourhood", "bathrooms_text"]].fillna(method="ffill")
# Out:
# C:\Users\angel\AppData\Local\Temp\ipykernel_3760\2611769699.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data2[["host_since", "host_neighbourhood", "bathrooms_text"]]=data2[["host_since", "host_neighbourhood", "bathrooms_text"]].fillna(method="ffill")

# %%
#Sustitucion de valores nulos con promedio o  media, decidi ocupar este metodo y dada la similitud de columnas, dado que los valores de cada columna suelen estar en casi el mismo rango de valor, asi que al sacar el promedio de cada columna y sustituirlo por lo valores nulos es una buena aproximacion de los valores.
data2[["host_acceptance_rate", "bedrooms", "beds", "price", "minimum_minimum_nights", "maximum_minimum_nights", "minimum_maximum_nights", "maximum_maximum_nights", "minimum_nights_avg_ntm", "maximum_nights_avg_ntm"]]=data2[["host_acceptance_rate", "bedrooms", "beds", "price", "minimum_minimum_nights", "maximum_minimum_nights", "minimum_maximum_nights", "maximum_maximum_nights", "minimum_nights_avg_ntm", "maximum_nights_avg_ntm"]].fillna(round(data1[["host_acceptance_rate", "bedrooms", "beds", "price", "minimum_minimum_nights", "maximum_minimum_nights", "minimum_maximum_nights", "maximum_maximum_nights", "minimum_nights_avg_ntm", "maximum_nights_avg_ntm"]].mean(),1))

# %%
#Sustitucion de valores nulos con valores no nulos hacia atras, decidi ocupar este metodo dado por el hecho de que hay varios anfritiones con varias propiedades y algunas si estan marcadas como verrdaderos y otros como falso y al ocupar este metodo se puede llenar con el hecho que lo puede ser o no, y dado con los valores de la tabla es una buena susticion para los valores nulos. 
data2[["host_is_superhost", "host_has_profile_pic", "host_identity_verified"]]=data2[["host_is_superhost", "host_has_profile_pic", "host_identity_verified"]].fillna(method="bfill")
# Out:
# C:\Users\angel\AppData\Local\Temp\ipykernel_3760\2426065164.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data2[["host_is_superhost", "host_has_profile_pic", "host_identity_verified"]]=data2[["host_is_superhost", "host_has_profile_pic", "host_identity_verified"]].fillna(method="bfill")

# %%
#Sustitucion de valores nulos por un valor numerico en concreto, este lo elegi dado que si no posee un valor es razonable suponer que tiene 0 anuncios activos
data2["host_total_listings_count"]=data2["host_total_listings_count"].fillna(0)

# %%
#Sustitucion de valores nulos por un valor de texto en concreto, al igual que el anterior este lo elegi dado que si no posee un valor es razonable suponer que su verificacion es desconocida.
data2["host_verifications"]=data2["host_verifications"].fillna("Unknown")

# %%
##Sustitucion de valores nulos por un valor de texto en concreto, al igual que los anteriores este lo escogi dado que si no tiene un valor parece razonable pensar que no esta disponible.
data2["has_availability"] = data2["has_availability"].fillna("unavailable")

# %%
#Sustituicion por mediana ya que las columnas pueden tener variabilidad y este metodo es más resistente a valores extraños o discrepancias que puede tener al ser columnas de reseñas,
data2[["review_scores_rating", "review_scores_cleanliness", "review_scores_checkin", "review_scores_communication", "review_scores_location", "review_scores_value", "reviews_per_month"]]=data2[["review_scores_rating", "review_scores_cleanliness", "review_scores_checkin", "review_scores_communication", "review_scores_location", "review_scores_value", "reviews_per_month"]].fillna(round(data1[["review_scores_rating", "review_scores_cleanliness", "review_scores_checkin", "review_scores_communication", "review_scores_location", "review_scores_value", "reviews_per_month"]].median(),1))

# %%
#Identificar valores nulos para dataframe
valores_nulos=data2.isnull().sum()
valores_nulos
# Out:
# last_scraped                                    0
# source                                          0
# description                                     0
# neighborhood_overview                           0
# host_name                                       0
# host_since                                      0
# host_response_time                              0
# host_acceptance_rate                            0
# host_is_superhost                               0
# host_neighbourhood                              0
# host_total_listings_count                       0
# host_verifications                              0
# host_has_profile_pic                            0
# host_identity_verified                          0
# neighbourhood_cleansed                          0
# latitude                                        0
# longitude                                       0
# property_type                                   0
# room_type                                       0
# ...

# %%
#Identificar valores nulos para dataframe
valores_nulos=data2.isnull().sum().sum()
valores_nulos
# Out:
# np.int64(0)

# %%
#Convertir DataFrame a csv
data2.to_csv('Datos_de_LosAngeles_EstadosUnidos_sin_nulos.csv')
